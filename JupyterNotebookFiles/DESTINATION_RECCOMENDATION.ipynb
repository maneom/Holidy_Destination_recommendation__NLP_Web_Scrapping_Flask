# %% [markdown]
# # IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # READING DATA SCRAPED FROM WEBSITE

# %%
df = pd.read_csv("data.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    100 non-null    object
#  1   url     100 non-null    object
#  2   desc    100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
df.isnull().sum()
# Out:
# city    0
# url     0
# desc    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['city'].nunique()
# Out:
# 100

# %% [markdown]
# __IN OUR DATA THERE ARE 100 UNIQUE CITIES IN INDIA__
#
# *In the future, if more cities are obtained, I will concatenate them to the same DataFrame and use the same approach for it.*

# %% [markdown]
# # TEXT PREPROCESSING

# %%
import string
from nltk.corpus import stopwords

# %%
# 1 . MAKING ALL TEXT IN DESCRIPTION LOWERCASE
df['desc'] = df['desc'].apply(str.lower)

# 2. REMOVING PUCUATION MARKS IF ANY
df['desc'] = df['desc'].apply(lambda x : "".join([i for i in x if i not in string.punctuation]))

# 3. REMOVING STOPWORDS
df['desc'] = df['desc'].apply(lambda x : " ".join([i for i in x.split() if i not in stopwords.words('english')]))

# 4. REMOVING ALL ALPHA-NUMERIC VALUES
df['desc'] = df['desc'].apply(lambda x : " ".join([i for i in x.split() if i.isalpha()]))

# %%
# PROCESSED DATAFRAME LOOKS LIKE
df.head(5)
# Out:
#        city                                                url  \
# 0  Srinagar  https://www.holidify.com/images/bgImages/SRINA...
# 1       Leh  https://www.holidify.com/images/bgImages/LADAK...
# 2   Gangtok  https://www.holidify.com/images/bgImages/GANGT...
# 3   Andaman  https://www.holidify.com/images/bgImages/ANDAM...
# 4    Manali  https://www.holidify.com/images/bgImages/MANAL...
#
#                                                 desc
# 0  famously known heaven earth srinagar located u...
# 1  ladakh union territory kashmir region india fo...
# 2  incredibly alluring pleasantly boisterous wrea...
# 3  replete turquoise blue water beaches bit histo...
# 4  spectacular valleys breathtaking views snowcap...

# %% [markdown]
# # VECTORIZATION

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=1000)
vector = cv.fit_transform(df['desc']).toarray()

# %%
vector.shape
# Out:
# (100, 1000)

# %%
list(cv.get_feature_names_out())
# Out:
# ['aap',
#  'absolutely',
#  'abu',
#  'accessibility',
#  'according',
#  'acres',
#  'across',
#  'activities',
#  'activity',
#  'adjacent',
#  'administered',
#  'adorned',
#  'adorns',
#  'adventure',
#  'aerial',
#  'agartala',
#  'ages',
#  'agra',
#  'ahmedabad',
#  'ahmednagar',
#  'airport',
#  'ajanta',
#  'ajmer',
#  'alappuzha',
#  'alibag',
#  'alibaug',
#  'alleppey',
#  'allures',
#  'alluring',
#  'almora',
#  'along',
#  'alongside',
#  'also',
#  'although',
#  'altitude',
#  'always',
#  'amalgamation',
#  'amarnath',
#  'ambarsar',
#  'amidst',
#  'amm',
#  'among',
#  'amongst',
#  'amritsar',
#  'amsterdam',
#  'ancient',
#  'andaman',
#  'andhra',
#  'anglong',
#  'announced',
#  'antiques',
#  'apart',
#  'apple',
#  'arabian',
#  'aravali',
#  'aravalli',
#  'architectural',
#  'architecture',
#  'area',
#  'areas',
#  'around',
#  'array',
#  'arrived',
#  'art',
#  'ashrams',
#  'asia',
#  'asiatic',
#  'assam',
#  'attained',
#  'attraction',
#  'attractions',
#  'attracts',
#  'auli',
#  'aurangabad',
#  'aurangzeb',
#  'away',
#  'ayurvedic',
#  'baba',
#  'back',
#  'backdrop',
#  'background',
#  'backpackers',
#  'backpacking',
#  'backwaters',
#  'balaji',
#  'bangalore',
#  'bank',
#  'banks',
#  'base',
#  'based',
#  'basil',
#  'basket',
#  'bastions',
#  'bay',
#  'bazaars',
#  'beach',
#  'beaches',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'became',
#  'believed',
#  'beloved',
#  'benaras',
#  'bengal',
#  'bengaluru',
#  'best',
#  'better',
#  'bh',
#  'bhubaneswar',
#  'biggest',
#  'bihar',
#  'bikaner',
#  'biosphere',
#  'birthplace',
#  'bit',
#  'blair',
#  'blanket',
#  'blend',
#  'blended',
#  'blessed',
#  'bloom',
#  'blue',
#  'boasting',
#  'boat',
#  'boating',
#  'bodh',
#  'bodhi',
#  'boisterous',
#  'bombay',
#  'bordered',
#  'bounded',
#  'breathtaking',
#  'bridge',
#  'bright',
#  'brilliant',
#  'british',
#  'britishers',
#  'buddha',
#  'buddhist',
#  'buddhists',
#  'building',
#  'buildings',
#  'built',
#  'bundelkhand',
#  'business',
#  'bustling',
#  'buzzing',
#  'ca',
#  'cafes',
#  'called',
#  'calm',
#  'camel',
#  'camels',
#  'camping',
#  'campus',
#  'canals',
#  'cantonment',
#  'cape',
#  'capit',
#  'capital',
#  'captivates',
#  'carbonite',
#  'carnatic',
#  'carvings',
#  'cascades',
#  'cave',
#  'caves',
#  'cent',
#  'centers',
#  'central',
#  'centre',
#  'centres',
#  'chances',
#  'chandigarh',
#  'chandigarhs',
#  'chandrabhaga',
#  'channel',
#  'chaos',
#  'char',
#  'charm',
#  'charminar',
#  'charming',
#  'chennai',
#  'cherrapunji',
#  'child',
#  'childhood',
#  'chishti',
#  'chittoor',
#  'chittorgarh',
#  'choice',
#  'churches',
#  'ci',
#  'cities',
#  'city',
#  'clean',
#  'cliff',
#  'cliffs',
#  'climate',
#  'close',
#  'closed',
#  'clouds',
#  'coast',
#  'coastal',
#  'coastline',
#  'cochin',
#  'coffee',
#  'coimbatore',
#  'colloquially',
#  'colonial',
#  'colony',
#  'colour',
#  'colourful',
#  'combined',
#  'come',
#  'commerce',
#  'commercial',
#  'commonly',
#  'communities',
#  'comorin',
#  'company',
#  'completely',
#  'complex',
#  'concurrently',
#  'connected',
#  'considered',
#  'construc',
#  'constructing',
#  'continuously',
#  'contrasts',
#  'convergence',
#  'coorg',
#  'coracle',
#  'corbett',
#  'corners',
#  'coromandel',
#  'corporation',
#  'cosmopolitan',
#  'cosy',
#  'country',
#  'courageous',
#  'course',
#  'covered',
#  'covering',
#  'create',
#  'created',
#  'crowd',
#  'crowded',
#  'crown',
#  'cry',
#  'cuisine',
#  'culminating',
#  'cultural',
#  'culture',
#  'cultures',
#  'currently',
#  'cutting',
#  'cyberabad',
#  'dal',
#  'dalhousie',
#  'dargah',
#  'darjeeling',
#  'dates',
#  'days',
#  'dazzling',
#  'dearth',
#  'decay',
#  'deciduous',
#  'declared',
#  'deep',
#  'dehradun',
#  'delhi',
#  'delicious',
#  'delight',
#  'dense',
#  'deodar',
#  'depth',
#  'derived',
#  'desert',
#  'destination',
#  'destinations',
#  'devi',
#  'devotees',
#  'dham',
#  'dharamsala',
#  'dharamshala',
#  'dharamshalafamous',
#  'dharmapuri',
#  'dhauladhar',
#  'different',
#  'digha',
#  'dilli',
#  'dilwara',
#  'direc',
#  'dirt',
#  'distance',
#  'district',
#  'districts',
#  'diverse',
#  'dominated',
#  'doon',
#  'dose',
#  'dotted',
#  'doubledecker',
#  'dramatic',
#  'dreams',
#  'drive',
#  'drops',
#  'dry',
#  'due',
#  'dunes',
#  'dynamic',
#  'dynasties',
#  'earlier',
#  'earth',
#  'ease',
#  'east',
#  'eastern',
#  'easy',
#  'eateries',
#  'eclectic',
#  'ecoregion',
#  'educational',
#  'elevation',
#  'ellora',
#  'emperor',
#  'empire',
#  'enchanted',
#  'enchanting',
#  'end',
#  'endangered',
#  'endless',
#  'enjoy',
#  'enlightenment',
#  'enshrined',
#  'enters',
#  'enveloped',
#  'era',
#  'erotic',
#  'erstwhile',
#  'especially',
#  'estates',
#  'etc',
#  'evergreen',
#  'every',
#  'evolved',
#  'example',
#  'existence',
#  'falls',
#  'famous',
#  'famously',
#  'fauna',
#  'feet',
#  'first',
#  'flora',
#  'food',
#  'foothills',
#  'forests',
#  'former',
#  'formerly',
#  'fort',
#  'four',
#  'full',
#  'ganga',
#  'gangtok',
#  'gaya',
#  'getaway',
#  'ghats',
#  'gir',
#  'glorious',
#  'goa',
#  'golden',
#  'great',
#  'green',
#  'greenery',
#  'growing',
#  'gujarat',
#  'gulmarg',
#  'gwalior',
#  'handicrafts',
#  'haridwar',
#  'heart',
#  'height',
#  'heritage',
#  'highest',
#  'hill',
#  'hills',
#  'hilltop',
#  'himachal',
#  'himalayan',
#  'himalayas',
#  'hindu',
#  'hinduisms',
#  'hippie',
#  'historic',
#  'historical',
#  'history',
#  'hogenakkal',
#  'holiday',
#  'holiest',
#  'holy',
#  'home',
#  'honeymoon',
#  'honeymooners',
#  'host',
#  'houseboats',
#  'however',
#  'hub',
#  'hyderabad',
#  'ideal',
#  'important',
#  'india',
#  'indian',
#  'indias',
#  'industrial',
#  'islands',
#  'jaipur',
#  'jaisalmer',
#  'jammu',
#  'jewel',
#  'jodhpur',
#  'jog',
#  'kangra',
#  'kanyakumari',
#  'karnataka',
#  'kasauli',
#  'kashmir',
#  'kasol',
#  'kerala',
#  'keralas',
#  'khajuraho',
#  'khandala',
#  'kings',
#  'km',
#  'kms',
#  'known',
#  'kodaikanal',
#  'konkan',
#  'kovalam',
#  'krishna',
#  'kumbh',
#  'ladakh',
#  'lagoons',
#  'lake',
#  'lakes',
#  'lakshadweep',
#  'land',
#  'landscape',
#  'landscapes',
#  'lanes',
#  'lanka',
#  'large',
#  'larger',
#  'largest',
#  'lavasa',
#  'lavish',
#  'least',
#  'leave',
#  'legacy',
#  'leisure',
#  'leopards',
#  'level',
#  'lies',
#  'life',
#  'lifestyles',
#  'lighthouse',
#  'like',
#  'lined',
#  'lions',
#  'listed',
#  'literally',
#  'literature',
#  'little',
#  'living',
#  'located',
#  'location',
#  'lofty',
#  'lonavala',
#  'longest',
#  'looks',
#  'lord',
#  'lot',
#  'lots',
#  'lotus',
#  'loved',
#  'lovers',
#  'lucknow',
#  'lush',
#  'luxurious',
#  'lying',
#  'madhya',
#  'madikeri',
#  'madras',
#  'madurai',
#  'magical',
#  'magnific',
#  'magnificence',
#  'magnificent',
#  'mahabaleshwar',
#  'maharashtra',
#  'majestic',
#  'major',
#  'makes',
#  'making',
#  'many',
#  'mathura',
#  'meadows',
#  'meghalaya',
#  'mela',
#  'metres',
#  'metropolis',
#  'metropolitan',
#  'millions',
#  'mistcovered',
#  'misty',
#  'modern',
#  'modernity',
#  'monasteries',
#  'monuments',
#  'mountains',
#  'mughal',
#  'multiple',
#  'mumbai',
#  'music',
#  'mussoorie',
#  'nadu',
#  'nainital',
#  'name',
#  'names',
#  'narayana',
#  'narrow',
#  'nasik',
#  'national',
#  'natural',
#  'naturally',
#  'nature',
#  'nawabs',
#  'near',
#  'nearby',
#  'nestled',
#  'network',
#  'new',
#  'newest',
#  'nickname',
#  'nicobar',
#  'nigeen',
#  'nightlife',
#  'nilgiri',
#  'nohkalikai',
#  'noisy',
#  'north',
#  'northeastern',
#  'northern',
#  'note',
#  'november',
#  'noyyal',
#  'number',
#  'numerous',
#  'nuts',
#  'oak',
#  'oaks',
#  'occupied',
#  'october',
#  'odisha',
#  'offering',
#  'offers',
#  'officially',
#  'often',
#  'old',
#  'oldest',
#  'oldworld',
#  'one',
#  'onehorned',
#  'ongoing',
#  'ooty',
#  'orchards',
#  'outskirts',
#  'overlooking',
#  'overnight',
#  'owes',
#  'oxford',
#  'pachmarhi',
#  'packed',
#  'paintings',
#  'palaces',
#  'pamban',
#  'pandya',
#  'panjal',
#  'panoramic',
#  'paradise',
#  'paradox',
#  'park',
#  'parks',
#  'part',
#  'parvati',
#  'past',
#  'pe',
#  'peaceful',
#  'peacetime',
#  'peaks',
#  'pedestrian',
#  'peek',
#  'peninsula',
#  'people',
#  'perched',
#  'perfect',
#  'perpetually',
#  'personalities',
#  'photographically',
#  'picturesque',
#  'pieces',
#  'pilgrimage',
#  'pine',
#  'pink',
#  'pir',
#  'pla',
#  'place',
#  'places',
#  'placing',
#  'plains',
#  'planet',
#  'planned',
#  'plantations',
#  'playing',
#  'pleasant',
#  'pleasantly',
#  'plunge',
#  'point',
#  'pointedly',
#  'pondicherry',
#  'pondy',
#  'poovar',
#  'popular',
#  'popularly',
#  'population',
#  'port',
#  'portofino',
#  'pot',
#  'pradesh',
#  'presently',
#  'primarily',
#  'private',
#  'producing',
#  'project',
#  'prominent',
#  'proudly',
#  'provides',
#  'puducherry',
#  'pune',
#  'punjab',
#  'punjabi',
#  'puri',
#  'pushka',
#  'pushkar',
#  'quaint',
#  'queen',
#  'quirky',
#  'raj',
#  'rajasthan',
#  'rajasthannbsp',
#  'rama',
#  'rameshwaram',
#  'range',
#  'ranges',
#  'ranging',
#  'rani',
#  'ranked',
#  'ranthambore',
#  'rapidly',
#  'ravines',
#  'raw',
#  'reasonably',
#  'referred',
#  'refined',
#  'regal',
#  'regarded',
#  'regarding',
#  'region',
#  'reigns',
#  'relaxed',
#  'religious',
#  'remaining',
#  'remembered',
#  'renowned',
#  'replete',
#  'resembles',
#  'reserve',
#  'reserves',
#  'resided',
#  'resort',
#  'resorts',
#  'respite',
#  'resplende',
#  'rest',
#  'retains',
#  'rhino',
#  'rich',
#  'richest',
#  'richly',
#  'ride',
#  'rides',
#  'right',
#  'rishikesh',
#  'river',
#  'rivers',
#  'ro',
#  'road',
#  'roads',
#  'rockcut',
#  'rocks',
#  'romantic',
#  'root',
#  'round',
#  'rowboats',
#  'roya',
#  'royal',
#  'ruins',
#  'ruled',
#  'rustic',
#  'sabarmati',
#  'sacred',
#  'sahyadri',
#  'sai',
#  'said',
#  'saint',
#  'salvation',
#  'samadhi',
#  'samudra',
#  'sanctuary',
#  'sand',
#  'sandstone',
#  'sarees',
#  'saris',
#  'satara',
#  'satpura',
#  'sauntering',
#  'say',
#  'scenery',
#  'scenic',
#  'sculptures',
#  'sea',
#  'seafood',
#  'seaport',
#  'seas',
#  'secon',
#  'second',
#  'secondhighest',
#  'secondlargest',
#  'selfsacr',
#  'sensibilities',
#  'sensuous',
#  'separated',
#  'serene',
#  'serves',
#  'serving',
#  'set',
#  'setting',
#  'seven',
#  'several',
#  'shacks',
#  'shadowed',
#  'shape',
#  'shared',
#  'sharif',
#  'shikaras',
#  'shikhars',
#  'shillong',
#  'shimla',
#  'shimoga',
#  'shipra',
#  'shirdi',
#  'shiva',
#  'shivalik',
#  'shivaling',
#  'shopping',
#  'shores',
#  'short',
#  'shrine',
#  'shrines',
#  'siachen',
#  'siblings',
#  'side',
#  'sighting',
#  'sights',
#  'significant',
#  'sikhism',
#  'sikkim',
#  'silicon',
#  'silk',
#  'single',
#  'site',
#  'sites',
#  'sits',
#  'situated',
#  'skiing',
#  'slice',
#  'slopes',
#  'small',
#  'smallest',
#  'snacks',
#  'sneak',
#  'snowcapped',
#  'snowcovered',
#  'snowdraped',
#  'sohra',
#  'solan',
#  'soon',
#  'sought',
#  'soughtafter',
#  'sounds',
#  'south',
#  'southeastern',
#  'southern',
#  'southernmost',
#  'southernmostpart',
#  'southwest',
#  'speaks',
#  'species',
#  'spectacular',
#  'spellbinding',
#  'spelled',
#  'spent',
#  'spice',
#  'spir',
#  'spiritual',
#  'spirituality',
#  'splits',
#  'spo',
#  'sports',
#  'sprawling',
#  'spread',
#  'spreading',
#  'squalid',
#  'squalor',
#  'sree',
#  'sri',
#  'srinagar',
#  'stands',
#  'state',
#  'stately',
#  'station',
#  'stationary',
#  'stations',
#  'stays',
#  'steeped',
#  'stellar',
#  'still',
#  'strawberries',
#  'streams',
#  'street',
#  'streets',
#  'stunning',
#  'stylistically',
#  'subdivisional',
#  'summer',
#  'sumptuous',
#  'sunny',
#  'surrounded',
#  'surroundings',
#  'system',
#  'taj',
#  'talala',
#  'tall',
#  'tamil',
#  'tanjore',
#  'tapestry',
#  'tasting',
#  'tea',
#  'telanaga',
#  'temple',
#  'temples',
#  'termed',
#  'terms',
#  'terracottapink',
#  'territories',
#  'territory',
#  'testament',
#  'textiles',
#  'thanjavur',
#  'thar',
#  'thats',
#  'thirdlargest',
#  'thiruvananthapuram',
#  'thousand',
#  'three',
#  'thrive',
#  'thriving',
#  'throughout',
#  'tibetan',
#  'tiger',
#  'tigers',
#  'time',
#  'tip',
#  'tiruma',
#  'tirumala',
#  'tirupati',
#  'together',
#  'top',
#  'toprated',
#  'total',
#  'tourism',
#  'tourist',
#  'town',
#  'tr',
#  'trading',
#  'tradition',
#  'traditional',
#  'traditionally',
#  'tranquil',
#  'translates',
#  'translating',
#  'travel',
#  'travellers',
#  'treasures',
#  'treasury',
#  'tree',
#  'trees',
#  'trekkers',
#  'trekking',
#  'treks',
#  'triangle',
#  'trikuta',
#  'trip',
#  'trips',
#  'tucked',
#  'turquoise',
#  'twin',
#  'two',
#  'udagamandalam',
#  'udaipur',
#  'ujjain',
#  'undoubtedly',
#  'unesco',
#  'unexplored',
#  'union',
#  'unique',
#  'university',
#  'unlike',
#  'unspoilt',
#  'untouched',
#  'upper',
#  'uttar',
#  'uttarakhand',
#  'vacationers',
#  'vaishnavi',
#  'vaishno',
#  'valley',
#  'valleys',
#  'value',
#  'van',
#  'varanasi',
#  'various',
#  'varkala',
#  'vast',
#  'venkateshwara',
#  'verdant',
#  'vibrant',
#  'victorian',
#  'view',
#  'viewpoints',
#  'views',
#  'village',
#  'villas',
#  'virgin',
#  'visakhapatnam',
#  'visit',
#  'visited',
#  'visitors',
#  'vizag',
#  'volumes',
#  'vrinda',
#  'vrindavan',
#  'walls',
#  'water',
#  'waterfall',
#  'waterfalls',
#  'wayanad',
#  'weather',
#  'weekend',
#  'welcomes',
#  'welcoming',
#  'well',
#  'west',
#  'western',
#  'wettest',
#  'wildlife',
#  'winding',
#  'wine',
#  'winter',
#  'wonders',
#  'world',
#  'worldheritage',
#  'worlds',
#  'worshippers',
#  'woven',
#  'wreathed',
#  'wrong',
#  'yamuna',
#  'year',
#  'years']

# %% [markdown]
# __EACH CITY DESCRIPTION IS CONVERTED TO VECTOR WITH 1000 MOST FREQUENT FETURES__

# %% [markdown]
# # COSINE SIMILARITY

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vector)
similarity.shape
# Out:
# (100, 100)

# %% [markdown]
# __IT GIVES COSINE SIMILARITY OF EACH CITY WITH EVERY OTHER CITY__

# %%
# COSINE SIMILARITY OS SRINAGAR WITH EVERY OTHER CITY
similarity[0]
# Out:
# array([1.        , 0.17521916, 0.        , 0.05634362, 0.06172134,
#        0.08748178, 0.11461365, 0.1385685 , 0.        , 0.05730683,
#        0.02608203, 0.        , 0.07715167, 0.03086067, 0.10744306,
#        0.05372153, 0.02727724, 0.05939139, 0.1385685 , 0.02686077,
#        0.03086067, 0.05292561, 0.        , 0.        , 0.03026138,
#        0.08451543, 0.09449112, 0.12858612, 0.        , 0.05634362,
#        0.        , 0.14847847, 0.03217447, 0.        , 0.0554274 ,
#        0.        , 0.        , 0.02865341, 0.0277137 , 0.        ,
#        0.13041013, 0.0831411 , 0.19094065, 0.05216405, 0.0554274 ,
#        0.05939139, 0.        , 0.05832118, 0.08478078, 0.06299408,
#        0.08451543, 0.02326211, 0.10910895, 0.09869275, 0.0554274 ,
#        0.07319251, 0.05634362, 0.        , 0.        , 0.08908708,
#        0.05939139, 0.04600437, 0.        , 0.05372153, 0.04941662,
#        0.        , 0.        , 0.02865341, 0.10432811, 0.        ,
#        0.0277137 , 0.05143445, 0.12104551, 0.05730683, 0.08451543,
#        0.02916059, 0.        , 0.02409813, 0.02916059, 0.        ,
#        0.        , 0.11878277, 0.08908708, 0.02686077, 0.0277137 ,
#        0.        , 0.23816526, 0.09412416, 0.0277137 , 0.16366342,
#        0.08451543, 0.02160679, 0.02608203, 0.08908708, 0.        ,
#        0.0554274 , 0.        , 0.06579517, 0.03149704, 0.        ])

# %% [markdown]
# # CREATING FUNCTION TO TAKE INPUT

# %%
def simillarCity(name):
    data = pd.DataFrame(columns=['city', 'url', 'desc'])                                         # CREATING EMPTY DATAFRAME TO STORE RECOMMENDATIONS
    cityIndex  = df[df['city'] == name].index[0]                                                 # FINDING INDEX OF SEARCED CITY IN DATAFRAME
    cosineSimillarity = list(enumerate(similarity[cityIndex]))                                   # FINDING COSINE SIMILARITY OF SEARCHED CITY WITH OTHER
    relatedCityDistance = sorted(cosineSimillarity, reverse=True, key= lambda x : x[1])[0:15]    # SORTING(DESCENDING) COSINE SIMILLARITY BASED 
    for city in relatedCityDistance:
        j = city[0]
        data = pd.concat((data, pd.DataFrame([originalData.iloc[j]])))                           # STORING TO DATAFRAME
    return(data)

# %%
simillarCity('Mahabaleshwar')
# Out:
#              city                                                url  \
# 59  Mahabaleshwar  https://www.holidify.com/images/bgImages/MAHAB...
# 13         Munnar  https://www.holidify.com/images/bgImages/MUNNA...
# 28       Lonavala  https://www.holidify.com/images/bgImages/LONAV...
# 21       Nainital  https://www.holidify.com/images/bgImages/NAINI...
# 76       Khandala  https://www.holidify.com/images/bgImages/KHAND...
# 49        Alibaug  https://www.holidify.com/images/bgImages/ALIBA...
# 79       Matheran  https://www.holidify.com/images/bgImages/MATHE...
# 25      Mussoorie  https://www.holidify.com/images/bgImages/MUSSO...
# 74    Dharamshala  https://www.holidify.com/images/bgImages/DHARA...
# 18      Rishikesh  https://www.holidify.com/images/bgImages/RISHI...
# 17           Ooty  https://www.holidify.com/images/bgImages/OOTY.jpg
# 78       Madikeri  https://www.holidify.com/images/bgImages/MADIK...
# 58           Auli  https://www.holidify.com/images/bgImages/AULI.jpg
# 34      Pachmarhi  https://www.holidify.com/images/bgImages/PACHM...
# 16          Coorg  https://www.holidify.com/images/bgImages/COORG...
#
#                                                  desc
# 59   Mahabaleshwar is a hill station located in th...
# 13   Famous for the tea estates, greenery, winding...
# 28   Situated in the Sahyadri range of the Western...
# 21   Nainital is a charming hill station located a...
# 76   Khandala is a popular hill station in Maharas...
# 49   Alibaug (also spelled as Alibag) is a small c...
# 79   Nestled amidst the Sahyadri range on the West...
# 25   Mussoorie is one of the most popular hill sta...
# 74   Dharamshala is a beautiful hill town in the D...
# 18   Located in the foothills of the Himalayas alo...
# 17   Nestled amidst Nilgiri hills, Ooty, also know...
# 78   Generally covered as a part of trips to Coorg...
# 58   Dotted with the apple orchards, old oaks, and...
# 34   Pachmarhi is the only hill station and is the...
# 16   Located amidst imposing mountains in Karnatak...

# %%
simillarCity('Haridwar')
# Out:
#            city                                                url  \
# 44     Haridwar  https://www.holidify.com/images/bgImages/HARID...
# 18    Rishikesh  https://www.holidify.com/images/bgImages/RISHI...
# 64      Mathura  https://www.holidify.com/images/bgImages/MATHU...
# 12     Varanasi  https://www.holidify.com/images/bgImages/VARAN...
# 38       Ujjain  https://www.holidify.com/images/bgImages/UJJAI...
# 82  Bhubaneswar  https://www.holidify.com/images/bgImages/BHUBA...
# 48     Tirupati  https://www.holidify.com/images/bgImages/TIRUP...
# 88         Puri  https://www.holidify.com/images/bgImages/PURI.jpg
# 87     Dehradun  https://www.holidify.com/images/bgImages/DEHRA...
# 15     Amritsar  https://www.holidify.com/images/bgImages/AMRIT...
# 72   Coimbatore  https://www.holidify.com/images/bgImages/COIMB...
# 50    Ahmedabad  https://www.holidify.com/images/bgImages/AHMED...
# 56      Madurai  https://www.holidify.com/images/bgImages/MADUR...
# 42      Vaishno  https://www.holidify.com/images/bgImages/VAISH...
# 69         Pune  https://www.holidify.com/images/bgImages/PUNE.jpg
#
#                                                  desc
# 44   Haridwar is one of the seven holiest cities i...
# 18   Located in the foothills of the Himalayas alo...
# 64   One of Hinduism's seven sacred cities, Mathur...
# 12   World's oldest living city, Varanasi - also k...
# 38   Ujjain, considered to be one of the holiest c...
# 82   Bhubaneswar, the temple city of India, once k...
# 48   Situated in the Chittoor district of Andhra P...
# 88   Puri in Odisha is one of the four must-visit ...
# 87   Dehradun is the capital city and the largest ...
# 15   Amritsar, colloquially known as Ambarsar, is ...
# 72   Often termed as 'Manchester of South India', ...
# 50   A rapidly growing metropolis, an industrial h...
# 56   Madurai, the cultural capital of Tamil Nadu, ...
# 42   Vaishno Devi is a temple town that's home to ...
# 69   Pune is a bustling metropolis of Maharashtra,...

# %%
simillarCity('Pune')
# Out:
#              city                                                url  \
# 69           Pune  https://www.holidify.com/images/bgImages/PUNE.jpg
# 50      Ahmedabad  https://www.holidify.com/images/bgImages/AHMED...
# 38         Ujjain  https://www.holidify.com/images/bgImages/UJJAI...
# 12       Varanasi  https://www.holidify.com/images/bgImages/VARAN...
# 71    Ranthambore  https://www.holidify.com/images/bgImages/RANTH...
# 88           Puri  https://www.holidify.com/images/bgImages/PURI.jpg
# 51          Kanha  https://www.holidify.com/images/bgImages/KANHA...
# 70      Vrindavan  https://www.holidify.com/images/bgImages/VRIND...
# 11         Jaipur  https://www.holidify.com/images/bgImages/JAIPU...
# 56        Madurai  https://www.holidify.com/images/bgImages/MADUR...
# 41        Chennai  https://www.holidify.com/images/bgImages/CHENN...
# 44       Haridwar  https://www.holidify.com/images/bgImages/HARID...
# 15       Amritsar  https://www.holidify.com/images/bgImages/AMRIT...
# 53         Mysore  https://www.holidify.com/images/bgImages/MYSOR...
# 68  Visakhapatnam  https://www.holidify.com/images/bgImages/VISAK...
#
#                                                  desc
# 69   Pune is a bustling metropolis of Maharashtra,...
# 50   A rapidly growing metropolis, an industrial h...
# 38   Ujjain, considered to be one of the holiest c...
# 12   World's oldest living city, Varanasi - also k...
# 71   This is one of the best tiger reserves of the...
# 88   Puri in Odisha is one of the four must-visit ...
# 51   Located in a central region of Madhya Pradesh...
# 70   One of the oldest cities on the banks of Yamu...
# 11   Jaipur, the capital city of Rajasthan, stands...
# 56   Madurai, the cultural capital of Tamil Nadu, ...
# 41   Formerly known as Madras, Chennai is the capi...
# 44   Haridwar is one of the seven holiest cities i...
# 15   Amritsar, colloquially known as Ambarsar, is ...
# 53   Famously known as The City of Palaces, it wou...
# 68   Visakhapatnam, also commonly known as Vizag, ...

# %% [markdown]
# # STORING COSINE SIMILLARITY VALUES TO PICKLE FILE

# %%
import pickle

# %%
pickle.dump(similarity, open("cosineSimmilarity.pkl", "wb"))
